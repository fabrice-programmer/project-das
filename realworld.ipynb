# %%
#REAL WORLD DATA ANALYSIS

# %% [markdown]
# #projectA001

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


data = pd.read_csv(r"C:\Users\user\Desktop\data science project a 001\stack-overflow-developer-survey-2020 (1)\survey_results_public.csv")
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
survey_rw_df = pd.read_csv(r"C:\Users\user\Desktop\data science project a 001\stack-overflow-developer-survey-2020 (1)\survey_results_public.csv")
survey_rw_df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
survey_rw_df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
schema_fname=r"c:\Users\user\Desktop\data science project a 001\stack-overflow-developer-survey-2020 (1)\survey_results_schema.csv"
schema_rw = pd.read_csv(schema_fname, index_col="Column").QuestionText

schema_rw
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
schema_rw["YearsCodePro"]
# Out:
# 'NOT including education, how many years have you coded professionally (as a part of your work)?'

# %%
selected_columns = [
    # demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    'UndergradMajor',

    # programming experience
    'Hobbyist',
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    'LanguageWorkedWith',
    'LanguageDesireNextYear',
    'NEWLearn',
    'NEWStuck',

    # employment
    'Employment',
    'DevType',
    'WorkWeekHrs',
    'JobSat',
    'JobFactors',
    'NEWOvertime',
    'NEWEdImpt'
]

# %%
len(selected_columns)
# Out:
# 20

# %%
survey_df=survey_rw_df[selected_columns].copy()
schema=schema_rw[selected_columns]

# %%
survey_df
# Out:
#                   Country   Age Gender  \
# 0                 Germany   NaN    Man
# 1          United Kingdom   NaN    NaN
# 2      Russian Federation   NaN    NaN
# 3                 Albania  25.0    Man
# 4           United States  31.0    Man
# ...                   ...   ...    ...
# 64456       United States   NaN    NaN
# 64457             Morocco   NaN    NaN
# 64458            Viet Nam   NaN    NaN
# 64459              Poland   NaN    NaN
# 64460               Spain   NaN    NaN
#
#                                                EdLevel  \
# 0      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 1         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2                                                  NaN
# 3      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 4         Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                ...
# 64456  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
schema
# Out:
# Column
# Country                                                  Where do you live?
# Age                       What is your age (in years)? If you prefer not...
# Gender                    Which of the following describe you, if any? P...
# EdLevel                   Which of the following best describes the high...
# UndergradMajor                        What was your primary field of study?
# Hobbyist                                            Do you code as a hobby?
# Age1stCode                At what age did you write your first line of c...
# YearsCode                 Including any education, how many years have y...
# YearsCodePro              NOT including education, how many years have y...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# NEWLearn                  How frequently do you learn a new language or ...
# ...

# %%
survey_df['Age1stCode'] = pd.to_numeric(survey_df.Age1stCode,errors='coerce')
survey_df['YearsCode'] = pd.to_numeric(survey_df.YearsCode,errors='coerce')
survey_df['YearsCodePro'] = pd.to_numeric(survey_df.YearsCodePro,errors='coerce')
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro   WorkWeekHrs
# count  45069.000000  57028.000000  56340.000000  43795.000000  40814.000000
# mean      30.848432     15.485078     12.791480      8.882041     40.026994
# std        9.572541      5.113882      9.498417      7.768036     10.625955
# min       10.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000      6.000000      3.000000     40.000000
# 50%       29.000000     15.000000     10.000000      6.000000     40.000000
# 75%       35.000000     18.000000     17.000000     12.000000     43.000000
# max      279.000000     85.000000     50.000000     50.000000    140.000000

# %%
survey_df.drop(survey_df[survey_df.Age<10].index,inplace=True)
survey_df.drop(survey_df[survey_df.Age<10].index,inplace=True)
survey_df.drop(survey_df[survey_df.WorkWeekHrs>140].index,inplace=True)
survey_df['Gender'].value_counts()
# Out:
# Man                                                  45896
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
survey_df.where(~survey_df['Gender'].str.contains(';', na=False), np.nan, inplace=True)
survey_df['Gender'].value_counts()
# Out:
# Man                                                  45896
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
survey_df.sample(1)
# Out:
#       Country   Age Gender                                       EdLevel  \
# 27419   Kenya  27.0    Man  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                           UndergradMajor Hobbyist  Age1stCode  \
# 27419  Another engineering discipline (such as civil,...      Yes        21.0
#
#        YearsCode  YearsCodePro LanguageWorkedWith LanguageDesireNextYear  \
# 27419        8.0           NaN             Python                 Python
#
#             NEWLearn                                           NEWStuck  \
# 27419  Once a decade  Visit Stack Overflow;Visit another developer c...
#
#                Employment                DevType  WorkWeekHrs JobSat  \
# 27419  Employed full-time  Developer, full-stack          NaN    NaN
#
#       JobFactors NEWOvertime       NEWEdImpt
# 27419        NaN         NaN  Very important

# %%
import seaborn as sns
import matplotlib

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] =(9,5)
matplotlib.rcParams['figure.facecolor'] ='#00000000'

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
top_countries=survey_df.Country.value_counts().head(7)
top_countries
# Out:
# United States     12371
# India              8364
# United Kingdom     3881
# Germany            3864
# Canada             2175
# France             1884
# Brazil             1804
# Name: Country, dtype: int64

# %%
plt.figure(figsize=(12,5))
plt.xticks(rotation=75)
plt.title("Countries Distribution")
sns.barplot(x=top_countries.index, y=top_countries)
# Out:
# <Axes: title={'center': 'Countries Distribution'}, ylabel='Country'>

# %%
plt.figure(figsize=(12,6))
plt.title("Age Distribution")
plt.xlabel("age")
plt.ylabel("Number of respondents")
plt.hist(survey_df.Age.dropna(), bins=np.arange(10, 80, 5), color='purple')
# Out:
# (array([  209.,  2419.,  9135., 11938.,  8739.,  5582.,  3031.,  1756.,
#          1038.,   622.,   333.,   143.,    75.]),
#  array([10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60., 65., 70.,
#         75.]),
#  <BarContainer object of 13 artists>)

# %%
schema.Gender
gender_acounts=survey_df.Gender.value_counts(dropna=True)
gender_acounts
# Out:
# Man                                                  45896
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('gender_acounts')
plt.pie(gender_acounts,labels=gender_acounts.index,autopct='%1.1f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x1ed75c1b3a0>,
# ...
#  [Text(-0.2876084136924591, -1.0617350895460258, 'Man'),
#   Text(0.313146462130243, 1.0544853214982712, 'Woman'),
#   Text(0.02654530824587836, 1.0996796563591287, 'Non-binary, genderqueer, or gender non-conforming')],
#  [Text(-0.1568773165595231, -0.5791282306614686, '91.6%'),
#   Text(0.1708071611619507, 0.5751738117263296, '7.7%'),
#   Text(0.014479259043206376, 0.5998252671049792, '0.8%')])

# %%
plt.figure(figsize=(12,12))
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75)
plt.title(schema['EdLevel'])
plt.ylabel(None);

# %%
schema.UndergradMajor
undergrad_pct=survey_df.UndergradMajor.value_counts()*100/survey_df.UndergradMajor.count()
plt.ylabel(None);
plt.xlabel('percentage');
plt.title(schema.UndergradMajor)
sns.barplot(x=undergrad_pct,y=undergrad_pct.index)
# Out:
# <Axes: title={'center': 'What was your primary field of study?'}, xlabel='UndergradMajor'>

# %%
schema.Employment
# Out:
# 'Which of the following best describes your current employment status?'

# %%
import pandas as pd
import matplotlib.pyplot as plt

(survey_df['Employment'].value_counts(normalize=True, ascending=True) * 100).plot(
    kind='barh',
    color='g'
)

plt.xlabel("Percentage (%)")
plt.ylabel("Employment Status")
plt.title("Employment Distribution")
plt.show()

# %%
schema.DevType
# Out:
# 'Which of the following describe you? Please select all that apply.'

# %%
survey_df.DevType
# Out:
# 0        Developer, desktop or enterprise applications;...
# 1                  Developer, full-stack;Developer, mobile
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
#                                ...
# 64456                                  Senior executive/VP
# 64457                                                  NaN
# 64458                                                  NaN
# 64459                                                  NaN
# 64460                                                  NaN
# Name: DevType, Length: 64307, dtype: object

# %%
# those are code that we use to change column and different option like true and false in just new table 
#each respondant with it value

def split_multicolumn(col_series):
    result_df = col_series.to_frame()
    options = []
    for idx, value in col_series[col_series.notnull()].iteritems():
        for option in value.split(';'):
            
            if not option in result_df.columns:
                options.append(option)
                result_df[option] = False
            result_df.at[idx, option] = True
    options = list(set(options))
    return result_df[options]

dev_type_df = split_multicolumn(survey_df.DevType)

dev_type_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15028\89266713.py:7: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for idx, value in col_series[col_series.notnull()].iteritems():
#        Developer, mobile  Developer, QA or test  \
# 0                  False                  False
# 1                   True                  False
# 2                  False                  False
# 3                  False                  False
# 4                  False                  False
# ...                  ...                    ...
# 64456              False                  False
# 64457              False                  False
# 64458              False                  False
# 64459              False                  False
# 64460              False                  False
#
#        Marketing or sales professional  System administrator  \
# 0                                False                 False
# ...

# %%
dev_type_totals=dev_type_df.sum().sort_values(ascending=False)
dev_type_totals
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9407
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# ...

# %%
dev_type_totals
# Out:
# Developer, back-end                              26996
# Developer, full-stack                            26915
# Developer, front-end                             18128
# Developer, desktop or enterprise applications    11687
# Developer, mobile                                 9407
# DevOps specialist                                 5915
# Database administrator                            5658
# Designer                                          5262
# System administrator                              5185
# Developer, embedded applications or devices       4701
# Data or business analyst                          3970
# Data scientist or machine learning specialist     3939
# Developer, QA or test                             3893
# Engineer, data                                    3700
# Academic researcher                               3502
# Educator                                          2895
# Developer, game or graphics                       2751
# ...

# %%
survey_df.LanguageWorkedWith
# Out:
# 0                                   C#;HTML/CSS;JavaScript
# 1                                         JavaScript;Swift
# 2                                 Objective-C;Python;Swift
# 3                                                      NaN
# 4                                        HTML/CSS;Ruby;SQL
#                                ...
# 64456                                                  NaN
# 64457    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# 64458                                                  NaN
# 64459                                             HTML/CSS
# 64460                      C#;HTML/CSS;Java;JavaScript;SQL
# Name: LanguageWorkedWith, Length: 64307, dtype: object

# %%
languages_worked_df=split_multicolumn(survey_df.LanguageWorkedWith)
languages_worked_df
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15028\89266713.py:7: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for idx, value in col_series[col_series.notnull()].iteritems():
#          C++     C#  JavaScript    SQL   Java  Haskell     Go  Assembly  \
# 0      False   True        True  False  False    False  False     False
# 1      False  False        True  False  False    False  False     False
# 2      False  False       False  False  False    False  False     False
# 3      False  False       False  False  False    False  False     False
# 4      False  False       False   True  False    False  False     False
# ...      ...    ...         ...    ...    ...      ...    ...       ...
# 64456  False  False       False  False  False    False  False     False
# 64457   True   True        True   True   True     True   True      True
# 64458  False  False       False  False  False    False  False     False
# ...

# %%
language_worked_percentages=languages_worked_df.mean().sort_values(ascending=False)*100
language_worked_percentages
# Out:
# JavaScript               59.892391
# HTML/CSS                 55.801079
# SQL                      48.444182
# Python                   39.000420
# Java                     35.618206
# Bash/Shell/PowerShell    29.239430
# C#                       27.802572
# PHP                      23.129675
# TypeScript               22.461007
# C++                      21.115897
# C                        19.235853
# Go                        7.758098
# Kotlin                    6.887275
# Ruby                      6.229493
# Assembly                  5.447307
# VBA                       5.394436
# Swift                     5.226492
# R                         5.064767
# Rust                      4.498733
# Objective-C               3.603029
# Dart                      3.517502
# Scala                     3.150512
# Perl                      2.757087
# Haskell                   1.861384
# Julia                     0.782185
# dtype: float64

# %%
plt.figure(figsize=(12,12))
sns.barplot(x=language_worked_percentages,y=language_worked_percentages.index)
plt.title('Language used in the past year');
plt.xlabel('count');

# %%
languages_interested_df=split_multicolumn(survey_df.LanguageDesireNextYear)
languages_interested_percentages=languages_interested_df.mean().sort_values(ascending=False)*100
languages_interested_percentages
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_15028\89266713.py:7: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for idx, value in col_series[col_series.notnull()].iteritems():
# Python                   41.143266
# JavaScript               40.424837
# HTML/CSS                 32.027618
# SQL                      30.799135
# TypeScript               26.451242
# C#                       21.058361
# Java                     20.464335
# Go                       19.431788
# Bash/Shell/PowerShell    18.057132
# Rust                     16.270390
# C++                      15.013918
# Kotlin                   14.760446
# PHP                      10.947486
# C                         9.359790
# Swift                     8.694232
# Dart                      7.308691
# R                         6.571602
# Ruby                      6.425428
# Scala                     5.326014
# Haskell                   4.593590
# ...

# %%
plt.figure(figsize=(12,12))
sns.barplot(x=languages_interested_percentages,y=languages_interested_percentages.index)
plt.title('Languages people are intersted in learning over the next year');
plt.xlabel('count');

# %%
language_loved_df=languages_worked_df & languages_interested_df
language_loved_df
# Out:
#        Assembly  Bash/Shell/PowerShell      C     C#    C++   Dart     Go  \
# 0         False                  False  False   True  False  False  False
# 1         False                  False  False  False  False  False  False
# 2         False                  False  False  False  False  False  False
# 3         False                  False  False  False  False  False  False
# 4         False                  False  False  False  False  False  False
# ...         ...                    ...    ...    ...    ...    ...    ...
# 64456     False                  False  False  False  False  False  False
# 64457      True                   True   True   True   True   True   True
# 64458     False                  False  False  False  False  False  False
# 64459     False                  False  False  False  False  False  False
# 64460     False                  False  False   True  False  False  False
#
#        HTML/CSS  Haskell   Java  ...   Perl  Python      R   Ruby   Rust  \
# ...

# %%
language_loved_percentages = (language_loved_df.sum()*100/languages_worked_df.sum()).sort_values(ascending=False)
language_loved_percentages
# Out:
# Rust                     86.069824
# TypeScript               67.114373
# Python                   66.598884
# Kotlin                   62.813276
# Go                       62.176789
# Dart                     62.068966
# Julia                    61.431412
# C#                       59.623021
# Swift                    59.476346
# JavaScript               58.353888
# SQL                      56.607710
# Bash/Shell/PowerShell    53.688241
# HTML/CSS                 53.494594
# Scala                    53.257651
# Haskell                  51.378446
# R                        44.427387
# Java                     44.108273
# C++                      43.412622
# Ruby                     42.735896
# PHP                      37.232755
# C                        32.983023
# Assembly                 29.089352
# Perl                     28.369994
# Objective-C              23.133362
# VBA                      19.458057
# dtype: float64

# %%
plt.figure(figsize=(12,12))
sns.barplot(x=language_loved_percentages,y=language_loved_percentages.index)
plt.title('Languages people are intersted in learning over the next year');
plt.xlabel('count');

# %%
countries_df = survey_df.groupby('Country')['WorkWeekHrs'].mean().sort_values(ascending=False)
countries_df
# Out:
# Country
# Kuwait             58.222222
# Iraq               52.153846
# Grenada            50.000000
# Maldives           47.300000
# Afghanistan        46.500000
#                      ...
# North Korea              NaN
# Saint Lucia              NaN
# Sierra Leone             NaN
# Solomon Islands          NaN
# Timor-Leste              NaN
# Name: WorkWeekHrs, Length: 183, dtype: float64

# %%
high_response_countries_df = countries_df.loc[
    survey_df['Country'].value_counts() > 250
].head(15)
high_response_countries_df
# Out:
# Country
# Iran             44.337748
# Israel           43.915094
# China            42.150000
# United States    41.802982
# Greece           41.402724
# Viet Nam         41.391667
# South Africa     41.023460
# Turkey           40.982143
# Sri Lanka        40.612245
# New Zealand      40.457551
# Belgium          40.444444
# Canada           40.208837
# Hungary          40.194340
# Bangladesh       40.097458
# India            40.090603
# Name: WorkWeekHrs, dtype: float64
